# %%
# %load_ext autoreload
# %autoreload 2

import os

import copy

import numpy as np
import matplotlib.pyplot as plt

from astropy import wcs
from astropy.io import fits
from astropy.table import Table, Column, hstack

from mrf.display import display_single, SEG_CMAP, draw_circles
from mrf.utils import img_cutout, extract_obj
from mrf.celestial import Celestial, Star
import sep

plt.rcParams['text.usetex'] = True
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Download DECaLS images and crop

# %%
from mrf.download import download_decals_cutout
#from kuaizi.download import download_decals_cutout
download_decals_cutout(226.3341906, 1.8119113, 180, 'g', layer='dr8', pixel_unit=False, output_name='decals')
# This larger one is used to get a better PSF
download_decals_cutout(226.3341906, 1.8119113, 400, 'g', layer='dr8', pixel_unit=False, output_name='decals_large')
# Out:
# decals_g.fits: 1.89MB [00:04, 382kB/s]
# decals_large_g.fits: 0.00B [00:00, ?B/s]
# # Downloading decals_g.fits finished!
# decals_large_g.fits: 9.34MB [00:11, 820kB/s]
# # Downloading decals_large_g.fits finished!

# %%
## Crop HST images
#hdu = fits.open('./hst_16284_01_wfc3_uvis_f475w_iedd01_drc.fits')
hdu = fits.open('./im_f475w_mbg_large.fits') # This file is (and must be) bkg-subtracted!
img = hdu[0].data.byteswap().newbyteorder()
bkg = sep.Background(img)
bkg.subfrom(img)
_ = img_cutout(img, wcs.WCS(hdu[0].header), 226.3346588, 1.8123696, size=[180, 180], pixel_scale=0.04, prefix='hst_g')

# %%
#hdu = fits.open('./hst_16284_01_wfc3_uvis_f606w_iedd01_drc.fits')
hdu = fits.open('./im_f606w_mbg_large.fits')
img = hdu[0].data.byteswap().newbyteorder()
bkg = sep.Background(img)
bkg.subfrom(img)
_ = img_cutout(img, wcs.WCS(hdu[0].header), 226.3346588, 1.8123696, size=[180, 180], pixel_scale=0.04, prefix='hst_r')

# %% [markdown]
# ### Working on deriving DECaLS PSF.
# Since the small DECaLS cutout doesn't have enough bright stars, we need to work on the larger DECaLS cutout to get a better DECaLS PSF.

# %%
img = fits.open('decals_large_g.fits')[0].data
hdr = fits.open('decals_large_g.fits')[0].header

# %%
objects, segmap = extract_obj(
    img,
    b=32,
    f=3,
    sigma=2.5,
    minarea=3,
    deblend_nthresh=32,
    deblend_cont=0.003,
    sky_subtract=True,
    show_fig=True,
    flux_aper=[15, 20],
)
objects.sort(keys='flux', reverse=True)

psf_cat = objects[:40]
mag = 22.5 - 2.5 * np.log10(psf_cat['flux'])
psf_cat.add_column(Column(data=mag, name='mag'))
psf_cat = psf_cat[psf_cat['b'] / psf_cat['a'] > 0.9]
psf_cat = psf_cat[psf_cat['mag'] < 20.5]
# Out:
# # Detect 1302 objects

# %%
draw_circles(img, psf_cat)

# %%
with open('./ngc5846-udg1-task-decals.yaml', 'r') as ymlfile:
    import yaml
    from mrf.task import Config
    cfg = yaml.safe_load(ymlfile)
    config = Config(cfg)
    config.complete_config() # auto-complete absent keywords

# %%
# Construct and stack `Stars`.
size = 2 * config.starhalo.halosize + 1
stack_set = np.zeros((len(psf_cat), size, size))
bad_indices = []
for i, obj in enumerate(psf_cat):
    try:
        sstar = Star(img, header=hdr, starobj=obj, 
                     halosize=config.starhalo.halosize, padsize=config.starhalo.padsize)
        cval = config.starhalo.cval
        if isinstance(cval, str) and 'nan' in cval.lower():
            cval = np.nan
        else:
            cval = float(cval)

        sstar.centralize(method=config.starhalo.interp)

        if config.starhalo.mask_contam is True:
            sstar.mask_out_contam(sigma=4.0, deblend_cont=0.0001, show_fig=False, verbose=False)
        if config.starhalo.norm == 'flux_ann':
            stack_set[i, :, :] = sstar.get_masked_image(cval=cval) / sstar.fluxann
        else:
            stack_set[i, :, :] = sstar.get_masked_image(cval=cval) / sstar.flux

    except Exception as e:
        stack_set[i, :, :] = np.ones((size, size)) * 1e9
        bad_indices.append(i)
        print(e)

# %%
from mrf.utils import psf_bkgsub
from astropy.stats import sigma_clip
from astropy.convolution import convolve, Box2DKernel

stack_set = np.delete(stack_set, bad_indices, axis=0)
median_psf = np.nanmedian(stack_set, axis=0)
median_psf = psf_bkgsub(median_psf, int(config.starhalo.edgesize))
median_psf = convolve(median_psf, Box2DKernel(2))
sclip = sigma_clip(stack_set, axis=0, maxiters=3)
sclip[sclip.mask] = np.nan

# %%
display_single(median_psf);

# %%
from mrf.utils import save_to_fits
save_to_fits(median_psf, 'median_psf.fits')

# %%
median_psf.shape
# Out:
# (49, 49)

# %% [markdown]
# ### Implement `mrf` task

# %%
from mrf.task import MrfTask
from astropy.convolution import Gaussian2DKernel
from mrf.utils import bright_star_mask

# %%
task = MrfTask('ngc5846-udg1-task-decals.yaml')
img_lowres = 'decals_g.fits'
img_hires_b = 'hst_g.fits'
img_hires_r = 'hst_r.fits'
certain_gal_cat = None
median_psf_file = './median_psf.fits'
results = task.run(img_lowres, img_hires_b, img_hires_r, certain_gal_cat, median_psf_file=median_psf_file, 
                   wide_psf=False, output_name='n5846', verbose=True, skip_resize=False, skip_SE=False, skip_mast=False)
# Out:
# 2021-01-11 18:07:14,907 Running Multi-Resolution Filtering (MRF) on "hst" and "decals" images!
# 2021-01-11 18:07:14,927 Magnify Dragonfly image with a factor of 3.0:
# 2021-01-11 18:07:16,538 Register high resolution image "hst_g.fits" with "decals_g.fits"
# 2021-01-11 18:07:19,763 Register high resolution image "hst_r.fits" with "decals_g.fits"
# 2021-01-11 18:07:22,859 Build flux models on high-resolution images: Blue band
# 2021-01-11 18:07:22,860     - sigma = 2.5, minarea = 2
# 2021-01-11 18:07:22,860     - deblend_cont = 0.00500, deblend_nthres = 32.0
# 2021-01-11 18:07:23,426     - Detect 2994 objects
# 2021-01-11 18:07:24,043 Build flux models on high-resolution images: Red band
# 2021-01-11 18:07:24,044     - sigma = 2.5, minarea = 2
# 2021-01-11 18:07:24,044     - deblend_cont = 0.00500, deblend_nthres = 32.0
# 2021-01-11 18:07:24,521     - Detect 2700 objects
# 2021-01-11 18:07:25,129 Make color correction to blue band, remove artifacts as well
# 2021-01-11 18:07:25,247     - color_term = 0.05
# 2021-01-11 18:07:25,252     - median_color (blue/red) = 0.44203
# 2021-01-11 18:07:25,584 Extract objects from color-corrected high resolution image with:
# 2021-01-11 18:07:25,585     - sigma = 2.5, minarea = 2
# 2021-01-11 18:07:25,586     - deblend_cont = 0.00500, deblend_nthres = 32.0
# 2021-01-11 18:07:26,114     - Detect 2984 objects
# 2021-01-11 18:07:26,233 Remove bright stars from this segmentation map, using SEP results.
# 2021-01-11 18:07:26,234     - Bright star limit = 20.5
# 2021-01-11 18:07:26,456     - 34 stars removed.
# 2021-01-11 18:07:27,324 Flux model from high resolution image has been built.
# 2021-01-11 18:07:27,347 Build convolving kernel to degrade high resolution image.
# 2021-01-11 18:07:27,749     - Rejected Object 10: flux deviation = -3.163
# 2021-01-11 18:07:27,786     - Rejected Object 11: flux deviation = -0.354
# 2021-01-11 18:07:27,823     - Rejected Object 12: flux deviation = 0.563
# 2021-01-11 18:07:27,898     - Rejected Object 14: flux deviation = 0.774
# 2021-01-11 18:07:27,970     - Rejected Object 16: flux deviation = 4.993
# 2021-01-11 18:07:28,007     - Rejected Object 17: flux deviation = 1.172
# 2021-01-11 18:07:28,056     - Rejected Object 18: flux deviation = 0.713
# 2021-01-11 18:07:28,132     - Rejected Object 20: flux deviation = 3.738
# 2021-01-11 18:07:28,173     - Rejected Object 21: flux deviation = 1.419
# 2021-01-11 18:07:28,212     - Rejected Object 22: flux deviation = 0.895
# 2021-01-11 18:07:28,252     - Rejected Object 23: flux deviation = 1.224
# 2021-01-11 18:07:28,328     - Rejected Object 25: flux deviation = 0.680
# 2021-01-11 18:07:28,434     - Rejected Object 28: flux deviation = 0.987
# 2021-01-11 18:07:28,483     - Rejected Object 29: flux deviation = 0.723
# 2021-01-11 18:07:28,485     - You have 16 good stars to generate the median kernel
# 2021-01-11 18:07:31,821     - Convolving image, this could be a bit slow @_@
# 2021-01-11 18:07:58,737 Compact objects has been subtracted from low-resolution image! Saved as "n5846_res.fits".
# 2021-01-11 18:07:58,768 Extract objects from compact-object-subtracted low-resolution image with:
# 2021-01-11 18:07:58,769     - sigma = 3.5, minarea = 3
# 2021-01-11 18:07:58,769     - deblend_cont = 0.00300, deblend_nthres = 32.0
# 2021-01-11 18:07:58,814     - Detect 263 objects
# 2021-01-11 18:07:58,845 Stack stars to get PSF model!
# 2021-01-11 18:07:58,846     - Match detected objects with previously discard stars
# 2021-01-11 18:07:58,908     - Get 6 stars to be stacked!
# 2021-01-11 18:07:59,035     - Median PSF is loaded!
# 2021-01-11 18:07:59,038 Draw star halo models onto the image, and subtract them!
# 2021-01-11 18:07:59,160 Bright star halos are subtracted!
# 2021-01-11 18:07:59,162 Clean the image!
# 2021-01-11 18:07:59,265     - Replace artifacts with void.
# 2021-01-11 18:07:59,312 The final result is saved as "n5846_final.fits"!
# 2021-01-11 18:07:59,313 The mask is saved as "n5846_mask.fits"!
# 2021-01-11 18:07:59,318 Determine surface brightness detection limit
# 2021-01-11 18:07:59,319     - Binning factors: dx = 229, dy = 229
# 2021-01-11 18:07:59,320     - Used bin area / True bin area = 0.99993
# 2021-01-11 18:07:59,352     - 1.0-sigma variation in counts = 0.0000 +- nan
# 2021-01-11 18:07:59,353     - 1.0-sigma surface brightness limit on 60 arcsec scale is inf +- 0.7526
# 2021-01-11 18:07:59,986 Task finished! (⁎⁍̴̛ᴗ⁍̴̛⁎)

# %% [markdown]
# ## Make a nice mask for this object

# %%
# Mask out compact sources, but dont mask the UDG itself (by drawing a circle centered at UDG)
model_mask = convolve(1e3 * results.lowres_model_compact.image / np.nansum(results.lowres_model_compact.image),
                      Gaussian2DKernel(1.5))
model_mask[model_mask < 0.01] = 0
model_mask[model_mask != 0] = 1

footprint = np.zeros_like(model_mask, dtype=bool)
sep.mask_ellipse(footprint, 343, 343, 20, 20, 0, r=4)
model_mask[footprint] = 0

# Mask out bright stars
totmask = bright_star_mask(model_mask.astype(bool), results.bright_star_cat, 
                           bright_lim=19.5, 
                           r=5)
totmask = convolve(totmask.astype(float), Box2DKernel(2))
totmask[totmask > 0] = 1

save_to_fits(totmask, 'n5846_g_slight_mask.fits', header=results.lowres_final.header)

img_slight_masked = results.lowres_final_unmask.image * (~totmask.astype(bool))

# %%
display_single(img_slight_masked);

# %%
## Also mask out other objects, which are not in the footprint of HST image

objects, segmap = extract_obj(
    np.abs(img_slight_masked),
    b=128,
    f=3,
    sigma=2.5,
    minarea=3,
    deblend_nthresh=32,
    deblend_cont=0.01,
    sky_subtract=True,
    show_fig=True,
    flux_aper=[15, 20],
)
objects.sort(keys='flux', reverse=True)
cen_y, cen_x = np.array(img_slight_masked.shape) // 2

segmap[segmap == segmap[cen_y, cen_x]] = 0
large_mask = (segmap != 0)
large_mask = convolve(large_mask, Gaussian2DKernel(1.5))
large_mask[large_mask < 0.2] = 0
large_mask[large_mask != 0] = 1
# Out:
# # Detect 78 objects

# %%
display_single(img_slight_masked * (~large_mask.astype(bool)));

# %%
save_to_fits(large_mask + totmask, 'n5846_g_full_mask.fits', header=results.lowres_final.header)

# %%
### Pymfit needs a INV-VAR matrix, here I simply estimate it as follows

save_to_fits(1 / np.abs(
    results.lowres_final_unmask.
    image), 'n5846_g_invvar.fits', header = results.lowres_final.header)

# %% [markdown]
# ### Display

# %%
from mrf.display import display_multiple
display_multiple(
    [
        results.lowres_input.image,
        results.lowres_final_unmask.image,
        img_slight_masked,
        img_slight_masked *
        (~large_mask.astype(bool))  #results.lowres_final.image
    ],
    text=['Image', 'Unmasked', 'Masked', 'Fully Masked'],
    text_fontsize=15,
    text_y_offset=0.9);

# %%
fig, [ax1, ax2] = plt.subplots(1, 2, figsize=(10, 5))
ax1 = display_single(results.kernel_med, ax=ax1, 
                     scale_bar=False, add_text='Kernel')
ax2 = display_single(results.PSF, ax=ax2, 
                     scale_bar=False, add_text='PSF')
