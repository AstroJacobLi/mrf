# %%
# %load_ext autoreload
# %autoreload 2

import os

import copy

import numpy as np
import matplotlib.pyplot as plt

from astropy import wcs
from astropy.io import fits
from astropy.table import Table, Column, hstack

from mrf.display import display_single, SEG_CMAP

plt.rcParams['text.usetex'] = True

# %% [markdown]
# ### First we download NGC 5907 images from CFHT Megacam, then bin them using 2*2 box and convolve with 1 pixel Gaussian

# %%
# Position of NGC 5907
ra, dec = 228.974042, 56.328771

# %%
# Notice: the images might be very large (several Gb)!
from mrf import download
download.download_highres('n5907_df_g.fits', high_res='cfht', band='g')
download.download_highres('n5907_df_r.fits', high_res='cfht', band='r')

# %%
from mrf.celestial import Celestial
from astropy.convolution import convolve, Gaussian2DKernel
hdu = fits.open('CFHT_megapipe_img_G.fits')
cfht = Celestial(hdu[0].data, header=hdu[0].header)
hdu.close()
cfht.resize_image(0.5)
cfht.image = convolve(cfht.image, Gaussian2DKernel(1))
cfht.save_to_fits('ngc5907_cfht_g.fits')

# %%
hdu = fits.open('CFHT_megapipe_img_R.fits')
cfht = Celestial(hdu[0].data, header=hdu[0].header)
hdu.close()
cfht.resize_image(0.5)
cfht.image = convolve(cfht.image, Gaussian2DKernel(1))
cfht.save_to_fits('ngc5907_cfht_r.fits')

# %% [markdown]
# ### Implement `mrf` task by providing directories of input images, along with galaxies you want to retain during `mrf`.

# %%
from mrf.task import MrfTask

# %%
task = MrfTask('ngc5907-task.yaml')
img_lowres = 'n5907_df_g.fits'
img_hires_b = 'ngc5907_cfht_g.fits'
img_hires_r = 'ngc5907_cfht_r.fits'
certain_gal_cat = 'gal_cat_n5907.txt'
results = task.run(img_lowres, img_hires_b, img_hires_r, certain_gal_cat, 
                   output_name='n5907', verbose=True)
# Out:
# 2019-08-15 16:46:38,046 Running Multi-Resolution Filtering (MRF) on "cfht" and "df" images!
# 2019-08-15 16:46:38,062 Subtract BACKVAL=460.2 of Dragonfly image
# 2019-08-15 16:46:38,076 Magnify Dragonfly image with a factor of 3.0:
# 2019-08-15 16:46:39,414 Register high resolution image "ngc5907_cfht_g.fits" with "n5907_df_g.fits"
# 2019-08-15 16:46:48,495 Register high resolution image "ngc5907_cfht_r.fits" with "n5907_df_g.fits"
# 2019-08-15 16:46:57,247 Build flux models on high-resolution images: Blue band
# 2019-08-15 16:46:57,248     - sigma = 2.5, minarea = 2
# 2019-08-15 16:46:57,249     - deblend_cont = 0.00500, deblend_nthres = 32.0
# 2019-08-15 16:47:02,498     - Detect 41638 objects
# 2019-08-15 16:48:00,187 Build flux models on high-resolution images: Red band
# 2019-08-15 16:48:00,188     - sigma = 2.5, minarea = 2
# 2019-08-15 16:48:00,189     - deblend_cont = 0.00500, deblend_nthres = 32.0
# 2019-08-15 16:48:04,151     - Detect 35661 objects
# 2019-08-15 16:48:51,926 Make color correction to blue band, remove artifacts as well
# 2019-08-15 16:48:52,176     - color_term = -0.05
# 2019-08-15 16:48:52,200     - median_color (blue/red) = 0.56419
# 2019-08-15 16:48:53,167 Extracting objects from color-corrected high resolution image with:
# 2019-08-15 16:48:53,168     - sigma = 2.5, minarea = 2
# 2019-08-15 16:48:53,169     - deblend_cont = 0.00500, deblend_nthres = 32.0
# 2019-08-15 16:48:59,247     - Detect 41620 objects
# 2019-08-15 16:49:00,114 Remove bright stars from this segmentation map, using SEP results.
# 2019-08-15 16:49:00,115     - Bright star limit = 17.5
# 2019-08-15 16:49:02,097     - 132 stars removed.
# 2019-08-15 16:49:02,097 Remove objects from catalog "gal_cat_n5907.txt"
# 2019-08-15 16:49:02,111     - Removing object 8670 from flux model
# 2019-08-15 16:49:02,142     - Removing object 19202 from flux model
# 2019-08-15 16:49:02,171     - Removing object 0 from flux model
# 2019-08-15 16:49:02,210     - Removing object 0 from flux model
# 2019-08-15 16:49:02,247     - Removing object 0 from flux model
# 2019-08-15 16:49:02,284     - Removing object 0 from flux model
# 2019-08-15 16:49:02,328     - Removing object 0 from flux model
# 2019-08-15 16:49:02,367     - Removing object 0 from flux model
# 2019-08-15 16:49:02,404     - Removing object 0 from flux model
# 2019-08-15 16:49:02,446     - Removing object 0 from flux model
# 2019-08-15 16:49:02,485     - Removing object 0 from flux model
# 2019-08-15 16:49:02,521     - Removing object 0 from flux model
# 2019-08-15 16:49:02,559     - Removing object 0 from flux model
# 2019-08-15 16:49:02,595     - Removing object 0 from flux model
# 2019-08-15 16:49:02,631     - Removing object 0 from flux model
# 2019-08-15 16:49:02,669     - Removing object 0 from flux model
# 2019-08-15 16:49:04,709 Flux model from high resolution image has been built.
# 2019-08-15 16:49:04,759 Build convolving kernel to degrade high resolution image.
# 2019-08-15 16:49:14,856     - You have 25 good stars to generate the median kernel
# 2019-08-15 16:49:16,851     - Convolving image, this could be a bit slow @_@
# 2019-08-15 16:49:21,361     - Removing low-SB objects from flux model.
# 2019-08-15 16:49:21,549     - Kernel flux = 0.5516401265200132
# 2019-08-15 16:49:21,564     - Maximum of flux_model / conv_model = 1506.502
# 2019-08-15 16:49:21,630     - SB limit in counts / pixel = 3.8622765770891294
# 2019-08-15 16:49:41,541     - Removed 16126 low surface brightness objects from flux model.
# 2019-08-15 16:49:43,556     - Convolving image, this could be a bit slow @_@
# 2019-08-15 16:49:51,104 Compact objects has been subtracted from low-resolution image! Saved as "n5907_res.fits".
# 2019-08-15 16:49:51,126 Extracting objects from compact-object-subtracted low-resolution image with:
# 2019-08-15 16:49:51,127     - sigma = 4.0, minarea = 5
# 2019-08-15 16:49:51,128     - deblend_cont = 0.00500, deblend_nthres = 32.0
# 2019-08-15 16:49:51,198     - Detect 215 objects
# 2019-08-15 16:49:51,216 Stack stars to get PSF model!
# 2019-08-15 16:49:51,217     - Match detected objects with previously discard stars
# 2019-08-15 16:49:51,270     - Get 30 stars to be stacked!
# 2019-08-15 16:49:55,206     - Stars are stacked successfully!
# 2019-08-15 16:49:55,211 Draw star halo models onto the image, and subtract them!
# 2019-08-15 16:50:03,023 Bright star halos are subtracted!
# 2019-08-15 16:50:03,024 Clean the image!
# 2019-08-15 16:50:03,230     - Replace artifacts with void.
# 2019-08-15 16:50:03,266 The final result is saved as "n5907_final.fits"!
# 2019-08-15 16:50:03,266 Delete all temporary files!
# 2019-08-15 16:50:03,735 Mission finished! (⁎⁍̴̛ᴗ⁍̴̛⁎)

# %% [markdown]
# ### The results are stored in `results`. You can simply show the `mrf` results as follows.

# %%
fig, [ax1, ax2, ax3] = plt.subplots(1, 3, figsize=(15, 8))
ax1 = display_single(results.lowres_input.image, ax=ax1, pixel_scale=2.0, 
                     scale_bar_length=300, scale_bar_y_offset=0.3, 
                     add_text='NGC\, 5907', text_y_offset=0.65)
ax2 = display_single(results.lowres_model.image, ax=ax2, scale_bar=False, 
                     add_text='Model', text_y_offset=0.65)
ax3 = display_single(results.lowres_final.image, ax=ax3, scale_bar=False, 
                     add_text='Redisual', text_y_offset=0.65)
plt.subplots_adjust(wspace=0.05)
plt.savefig('n5907-demo.png', bbox_inches='tight', facecolor='silver')

# %%
fig, [ax1, ax2] = plt.subplots(1, 2, figsize=(15, 8))
ax1 = display_single(results.lowres_input.image, ax=ax1, 
                     scale_bar=False, add_text='Kernel', text_y_offset=0.65)
ax2 = display_single(results.hires_fluxmod, ax=ax2, scale='percentile', lower_percentile=0.5,
                     scale_bar=False, add_text='FLux\,Model', text_y_offset=0.65)

# %%
fig, [ax1, ax2] = plt.subplots(1, 2, figsize=(15, 8))
ax1 = display_single(results.kernel_med, ax=ax1, 
                     scale_bar=False, add_text='Kernel')
ax2 = display_single(results.PSF, ax=ax2, 
                     scale_bar=False, add_text='PSF')
